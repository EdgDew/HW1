# %%
require(MASS)
# Out:
# Loading required package: MASS
# Warning message:
# In library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, : there is no package called ‘MASS’

# %%
install.packages("MASS", repos="http://cran.rstudio.com/")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
require (MASS)
# Out:
# Loading required package: MASS

# %%
M = matrix(c(1,2,3),3,2)

# %%
M
# Out:
#      [,1] [,2]
# [1,]    1    1
# [2,]    2    2
# [3,]    3    3

# %%
beta = 0.5
SIGMA = matrix(c(1,beta,beta,1), ncol=2)
MU = c(2.0, 1.0)

N = 50

out <- mvrnorm(N, mu = MU, Sigma = SIGMA)

# %%
out
# Out:
#            [,1]         [,2]
#  [1,] 0.8279377 -1.032072211
#  [2,] 0.5823634  0.006077174
#  [3,] 1.6348744  1.298436708
#  [4,] 1.7151604  1.031832993
#  [5,] 3.8077824  1.901594242
#  [6,] 3.0313385  0.962414537
#  [7,] 3.0931195  2.108257282
#  [8,] 1.8429797  0.133788923
#  [9,] 2.2617014  1.991742743
# [10,] 1.0421727  1.188996667
# [11,] 2.5822807  0.800806602
# [12,] 1.0690286 -0.195846735
# [13,] 2.0446868  0.183496913
# [14,] 2.0909270  1.358199207
# [15,] 1.6308258  1.790523732
# [16,] 3.2818611  0.557900210
# [17,] 1.2738481 -0.562812613
# [18,] 2.5711046  2.471037094
# [19,] 1.7176508 -0.951977176
# [20,] 2.8401714  2.091704162
# [21,] 1.7248045  0.721078535
# [22,] 0.4404308 -0.027731460
# [23,] 2.9775541  1.769826463
# [24,] 0.4760800  0.818920640
# [25,] 3.3708208  0.805174080
# [26,] 1.5189689  1.836781954
# [27,] 2.2438714  1.537762897
# [28,] 2.5549560  1.403864011
# [29,] 3.3087877 -0.466089515
# [30,] 1.9876660  1.414913341
# [31,] 1.2756359 -0.124293705
# [32,] 2.0876013  1.531859761
# [33,] 2.2517004  0.188946872
# [34,] 0.3357919 -0.787687862
# [35,] 0.9911253 -0.839238044
# [36,] 0.9551938  0.129799012
# [37,] 2.6112786  0.987817336
# [38,] 2.5954203  0.844711727
# [39,] 1.5697108  1.730621825
# [40,] 0.4342195  0.826363999
# [41,] 3.1237750  1.425649551
# [42,] 2.3569676  2.363672192
# [43,] 4.8833847  2.617152464
# [44,] 1.3367120 -0.731071944
# [45,] 1.5220025  0.662774540
# [46,] 4.7519987  2.643068876
# [47,] 2.4191227  0.976026283
# [48,] 1.4193863  1.124054402
# [49,] 1.3513645  0.174843714
# [50,] 0.4834145 -1.500448655

# %%
out[1:10,]
# Out:
#            [,1]         [,2]
#  [1,] 0.8279377 -1.032072211
#  [2,] 0.5823634  0.006077174
#  [3,] 1.6348744  1.298436708
#  [4,] 1.7151604  1.031832993
#  [5,] 3.8077824  1.901594242
#  [6,] 3.0313385  0.962414537
#  [7,] 3.0931195  2.108257282
#  [8,] 1.8429797  0.133788923
#  [9,] 2.2617014  1.991742743
# [10,] 1.0421727  1.188996667
